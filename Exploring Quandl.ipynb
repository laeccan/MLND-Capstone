# %%
import quandl
data = quandl.get("FRED/GDP")

# By default, the data is returned as a pandas dataframe.  Quandl can also return data as a numpy array.  
# To explicitly specify the data download format, do this:

data = quandl.get("FRED/GDP",returns="pandas") 	# pandas data series
data = quandl.get("FRED/GDP",returns="numpy")		# numpy array

# %%
# data
# WIKI/AAPL appears to be method for Apple stock
data = quandl.get("WIKI/AAPL")
# data ...score! Apple stock data from 1980-12-12 to 2017-06-07
# need to review https://www.quandl.com/tools/api for more info
# and https://docs.quandl.com/
# Out:
#                 Open    High       Low     Close      Volume  Ex-Dividend  \
# Date
# 1980-12-12   28.7500   28.87   28.7500   28.7500   2093900.0         0.00
# 1980-12-15   27.3800   27.38   27.2500   27.2500    785200.0         0.00
# 1980-12-16   25.3700   25.37   25.2500   25.2500    472000.0         0.00
# 1980-12-17   25.8700   26.00   25.8700   25.8700    385900.0         0.00
# 1980-12-18   26.6300   26.75   26.6300   26.6300    327900.0         0.00
# 1980-12-19   28.2500   28.38   28.2500   28.2500    217100.0         0.00
# 1980-12-22   29.6300   29.75   29.6300   29.6300    166800.0         0.00
# 1980-12-23   30.8800   31.00   30.8800   30.8800    209600.0         0.00
# 1980-12-24   32.5000   32.63   32.5000   32.5000    214300.0         0.00
# 1980-12-26   35.5000   35.62   35.5000   35.5000    248100.0         0.00
# 1980-12-29   36.0000   36.13   36.0000   36.0000    415900.0         0.00
# 1980-12-30   35.2500   35.25   35.1200   35.1200    307500.0         0.00
# ...
